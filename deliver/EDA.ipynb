# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Basic Information

# %%
# compatability with python 3
from __future__ import print_function
print('Print is ready to serve.')

# N dim array & data frame support
import numpy as np
import pandas as pd

#plotting
import matplotlib.pyplot as plt

#show plots in notebooks
# %matplotlib inline

# seaborn for plotting as well
import seaborn as sns
# Out:
# Print is ready to serve.

# %%
df = pd.read_csv('../data/real_estate_data.csv')

# %%
df.shape
# Out:
# (1883, 26)

# %%
df.dtypes
# Out:
# tx_price                int64
# beds                    int64
# baths                   int64
# sqft                    int64
# year_built              int64
# lot_size                int64
# property_type          object
# exterior_walls         object
# roof                   object
# basement              float64
# restaurants             int64
# groceries               int64
# nightlife               int64
# cafes                   int64
# shopping                int64
# arts_entertainment      int64
# beauty_spas             int64
# active_life             int64
# median_age            float64
# married               float64
# college_grad          float64
# property_tax          float64
# insurance             float64
# median_school         float64
# num_schools           float64
# tx_year                 int64
# dtype: object

# %%
# get the few records
df.head(5)
# Out:
#    tx_price  beds  baths  sqft  year_built  lot_size  \
# 0    295850     1      1   584        2013         0
# 1    216500     1      1   612        1965         0
# 2    279900     1      1   615        1963         0
# 3    379900     1      1   618        2000     33541
# 4    340000     1      1   634        1992         0
#
#                    property_type exterior_walls                 roof  \
# 0  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 1  Apartment / Condo / Townhouse          Brick  Composition Shingle
# 2  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 3  Apartment / Condo / Townhouse    Wood Siding                  NaN
# 4  Apartment / Condo / Townhouse          Brick                  NaN
#
#    basement   ...     beauty_spas  active_life  median_age  married  \
# 0       NaN   ...              47           58        33.0     65.0
# 1       1.0   ...              26           14        39.0     73.0
# ...

# %% [markdown]
# ## Categorical Variables

# %%
print(df.dtypes[df.dtypes == 'object'])
# Out:
# property_type     object
# exterior_walls    object
# roof              object
# dtype: object

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index([u'property_type', u'exterior_walls', u'roof'], dtype='object')

# %%
for feature in df.dtypes[df.dtypes == 'object'].index:
    print(feature)
# Out:
# property_type
# exterior_walls
# roof

# %% [markdown]
# ## Distributions

# %% [markdown]
# ### Distributions of Numeric features

# %%
df.hist(figsize=(14,14), xrot=-45)
plt.show()

# %%
## get the statistics about the numeric features
df.describe()
# Out:
# /Users/admin/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             tx_price         beds        baths         sqft   year_built  \
# count    1883.000000  1883.000000  1883.000000  1883.000000  1883.000000
# mean   422839.807754     3.420605     2.579926  2329.398832  1982.963887
# std    151462.593276     1.068554     0.945576  1336.991858    20.295945
# min    200000.000000     1.000000     1.000000   500.000000  1880.000000
# 25%    300000.000000     3.000000     2.000000  1345.000000  1970.000000
# 50%    392000.000000     3.000000     3.000000  1907.000000  1986.000000
# 75%    525000.000000     4.000000     3.000000  3005.000000  2000.000000
# max    800000.000000     5.000000     6.000000  8450.000000  2015.000000
#
#            lot_size  basement  restaurants    groceries    nightlife  \
# count  1.883000e+03    1657.0  1883.000000  1883.000000  1883.000000
# ...

# %% [markdown]
# ### Distributions of Categorical features

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# property_type     object
# exterior_walls    object
# roof              object
# dtype: object

# %%
df.describe(include=['object'])
# Out:
#         property_type exterior_walls                 roof
# count            1883           1660                 1529
# unique              2             16                   16
# top     Single-Family          Brick  Composition Shingle
# freq             1080            687                 1179

# %%
# property type
sns.countplot(y='property_type', data=df)

# %%
# exterior walls
sns.countplot(y='exterior_walls', data=df)

# %%
# roof
sns.countplot(y='roof', data=df)

# %% [markdown]
# ## Segmentation
#
# The interaction between categorical and numeric variables.

# %%
# tx_price vs property_type
sns.boxplot(x='tx_price', y='property_type', data=df, )

# %%
# segment by property type and find the mean for each class
df.groupby('property_type').mean()
# Out:
#                                     tx_price      beds     baths         sqft  \
# property_type
# Apartment / Condo / Townhouse  366614.034869  2.601494  2.200498  1513.727273
# Single-Family                  464644.711111  4.029630  2.862037  2935.865741
#
#                                 year_built      lot_size  basement  \
# property_type
# Apartment / Condo / Townhouse  1988.936488   3944.239103       1.0
# Single-Family                  1978.523148  20417.666667       1.0
#
#                                restaurants  groceries  nightlife     ...       \
# property_type                                                        ...
# Apartment / Condo / Townhouse    58.418431   5.919054   7.855542     ...
# Single-Family                    26.672222   3.453704   3.007407     ...
#
#                                beauty_spas  active_life  median_age  \
# property_type
# Apartment / Condo / Townhouse    32.087173    22.410959   37.199253
# ...

# %%
# segment by sqft and property_type
sns.boxplot(x='sqft', y='property_type', data=df)

# %%
# find the mean and std for each property type
df.groupby('property_type').agg(['mean', 'std'])
# Out:
#                               tx_price                     beds            \
#                                   mean            std      mean       std
# property_type
# Apartment / Condo / Townhouse   366614  121784.490482  2.601494  0.810220
# Single-Family                   464644  157758.739010  4.029630  0.795639
#
#                                   baths                   sqft               \
#                                    mean       std         mean          std
# property_type
# Apartment / Condo / Townhouse  2.200498  0.815009  1513.727273   556.285898
# Single-Family                  2.862037  0.937551  2935.865741  1422.871041
#
#                                 year_built               ...    property_tax  \
#                                       mean        std    ...            mean
# property_type                                            ...
# Apartment / Condo / Townhouse  1988.936488  15.513640    ...      346.261519
# ...

# %% [markdown]
# ## Correlations

# %%
correlations = df.corr()

sns.heatmap(correlations)

# %%
# change background to white

sns.set_style('white')

plt.figure(figsize=(10,8))

#sns.heatmap(correlations)

sns.heatmap(correlations * 100, annot=True, fmt = '.0f')

# %%
# mask the upper triangle
correlations.shape
#np.zeros_like
# Out:
# (23, 23)

# %%
# get the array of booleans with same size of correlations
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize=(10,8))

# display heat map along with mask
sns.heatmap(correlations * 100, annot=True, fmt='.0f', mask=mask)
